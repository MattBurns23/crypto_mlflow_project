# %%
import pandas as pd

#Load the csv data
df = pd.read_csv("btc_quotes.csv")
df.head()
# Out:
#              timestamp          price    volume_24h  percent_change_1h  \
# 0  2025-06-14T03:07:15  105375.288025  5.542690e+10          -0.114180
# 1  2025-06-14T03:27:10  105369.325899  5.572533e+10          -0.145567
# 2  2025-06-14T15:50:20  104843.155030  4.001282e+10          -0.096693
# 3  2025-06-14T15:50:29  104843.155030  4.001282e+10          -0.096693
# 4  2025-06-14T15:50:31  104843.155030  4.001282e+10          -0.096693
#
#    percent_change_24h  percent_change_7d
# 0            1.461239           0.608094
# 1            1.039515           0.471448
# 2           -0.749482          -0.722681
# 3           -0.749482          -0.722681
# 4           -0.749482          -0.722681

# %%
# Check data types
df.dtypes
# Out:
# timestamp              object
# price                 float64
# volume_24h            float64
# percent_change_1h     float64
# percent_change_24h    float64
# percent_change_7d     float64
# dtype: object

# %%
# Check shape and duplicates
print("Shape:", df.shape)
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Shape: (74, 6)
# Duplicate rows: 1

# %%
# Strip whitespace just in case
df['timestamp'] = df['timestamp'].str.strip()

# Remove the "+00:00" from any timestamps
df['timestamp'] = df['timestamp'].str.replace(r'\+00:00', '', regex=True)
df
# Out:
#               timestamp          price    volume_24h  percent_change_1h  \
# 0   2025-06-14T03:07:15  105375.288025  5.542690e+10          -0.114180
# 1   2025-06-14T03:27:10  105369.325899  5.572533e+10          -0.145567
# 2   2025-06-14T15:50:20  104843.155030  4.001282e+10          -0.096693
# 3   2025-06-14T15:50:29  104843.155030  4.001282e+10          -0.096693
# 4   2025-06-14T15:50:31  104843.155030  4.001282e+10          -0.096693
# ..                  ...            ...           ...                ...
# 69  2025-06-19T19:00:05  104368.091732  3.978001e+10          -0.174803
# 70  2025-06-19T20:00:11  104317.658074  3.731709e+10          -0.048323
# 71  2025-06-19T21:00:09  104285.050861  3.756763e+10          -0.031258
# 72  2025-06-19T22:00:08  104322.033400  3.691929e+10           0.035463
# 73  2025-06-19T23:00:08  104641.883298  3.691674e+10           0.306599
#
#     percent_change_24h  percent_change_7d
# 0             1.461239           0.608094
# 1             1.039515           0.471448
# 2            -0.749482          -0.722681
# 3            -0.749482          -0.722681
# 4            -0.749482          -0.722681
# ..                 ...                ...
# 69            0.659596          -2.978086
# 70            0.368025          -2.338924
# 71           -0.544500          -1.623106
# 72           -0.645039          -1.530641
# 73           -0.197164          -1.218148
#
# [74 rows x 6 columns]

# %%
# Convert timestamp to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

# Check for any rows that failed conversion
print("Null timestamps after conversion:", df['timestamp'].isnull().sum())
# Out:
# Null timestamps after conversion: 0

# %%
# drop exact duplicates
df = df.drop_duplicates()
print("Shape after dropping duplicates:", df.shape)
# Out:
# Shape after dropping duplicates: (73, 6)

# %%
# Sort in Ascending order of time
df = df.sort_values('timestamp')

# Reset index
df = df.reset_index(drop=True)
df
# Out:
#              timestamp          price    volume_24h  percent_change_1h  \
# 0  2025-06-14 03:07:15  105375.288025  5.542690e+10          -0.114180
# 1  2025-06-14 03:27:10  105369.325899  5.572533e+10          -0.145567
# 2  2025-06-14 15:50:20  104843.155030  4.001282e+10          -0.096693
# 3  2025-06-14 15:50:29  104843.155030  4.001282e+10          -0.096693
# 4  2025-06-14 15:50:31  104843.155030  4.001282e+10          -0.096693
# ..                 ...            ...           ...                ...
# 68 2025-06-19 19:00:05  104368.091732  3.978001e+10          -0.174803
# 69 2025-06-19 20:00:11  104317.658074  3.731709e+10          -0.048323
# 70 2025-06-19 21:00:09  104285.050861  3.756763e+10          -0.031258
# 71 2025-06-19 22:00:08  104322.033400  3.691929e+10           0.035463
# 72 2025-06-19 23:00:08  104641.883298  3.691674e+10           0.306599
#
#     percent_change_24h  percent_change_7d
# 0             1.461239           0.608094
# 1             1.039515           0.471448
# 2            -0.749482          -0.722681
# 3            -0.749482          -0.722681
# 4            -0.749482          -0.722681
# ..                 ...                ...
# 68            0.659596          -2.978086
# 69            0.368025          -2.338924
# 70           -0.544500          -1.623106
# 71           -0.645039          -1.530641
# 72           -0.197164          -1.218148
#
# [73 rows x 6 columns]

# %%
# Save cleaned data
df.to_csv("btc_quotes_cleaned.csv", index=False)
print("✅ Cleaned dataset saved as 'btc_quotes_cleaned.csv'")
# Out:
# ✅ Cleaned dataset saved as 'btc_quotes_cleaned.csv'
